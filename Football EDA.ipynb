# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #  Read the Dataset

# %%
laliga = pd.read_csv("laliga.csv")

# %%
laliga
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      -           -        -          -
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %%
laliga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           61 non-null object
# GamesPlayed      61 non-null object
# GamesWon         61 non-null object
# GamesDrawn       61 non-null object
# GamesLost        61 non-null object
# GoalsFor         61 non-null object
# GoalsAgainst     61 non-null object
# Champion         61 non-null object
# Runner-up        61 non-null object
# Third            61 non-null object
# Fourth           61 non-null object
# Fifth            61 non-null object
# Sixth            61 non-null object
# T                61 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: int64(3), object(17)
# memory usage: 9.7+ KB

# %%
laliga.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points           object
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# dtype: object

# %%
laliga.describe(include = 'all')
# Out:
#               Pos        Team    Seasons Points GamesPlayed GamesWon  \
# count   61.000000          61  61.000000     61          61       61
# unique        NaN          61        NaN     61          53       59
# top           NaN  Las Palmas        NaN   1314          30        8
# freq          NaN           1        NaN      1           3        2
# mean    31.000000         NaN  24.000000    NaN         NaN      NaN
# std     17.752934         NaN  26.827225    NaN         NaN      NaN
# min      1.000000         NaN   1.000000    NaN         NaN      NaN
# 25%     16.000000         NaN   4.000000    NaN         NaN      NaN
# 50%     31.000000         NaN  12.000000    NaN         NaN      NaN
# 75%     46.000000         NaN  38.000000    NaN         NaN      NaN
# max     61.000000         NaN  86.000000    NaN         NaN      NaN
#
#        GamesDrawn GamesLost GoalsFor GoalsAgainst Champion Runner-up Third  \
# ...

# %%
laliga.shape
# Out:
# (61, 20)

# %%
laliga.columns
# Out:
# Index(['Pos', 'Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut',
#        'Since/LastApp', 'BestPosition'],
#       dtype='object')

# %% [markdown]
# # Replace dashes with 0 to make sure you can perform arithmetic operations on the data.

# %%
laliga.replace(to_replace = '-',value = 0, inplace = True)

# %%
laliga
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      0           0        0          0
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %% [markdown]
# # Print all the teams which have started playing between 1930-1980. Use “Debut” column

# %%
laliga['Debut']
# Out:
# 0        1929
# 1        1929
# 2        1929
# 3     1931-32
# 4        1929
#        ...
# 56    2009-10
# 57    1956-57
# 58    1951-52
# 59    1955-56
# 60    2017-18
# Name: Debut, Length: 61, dtype: object

# %%
laliga[(laliga['Debut']>='1930') & (laliga['Debut']<='1980')]['Team']
# Out:
# 3                Valencia
# 5                 Sevilla
# 8                Zaragoza
# 9              Real Betis
# 10    Deportivo La Coruna
# 11             Celta Vigo
# 12             Valladolid
# 14         Sporting Gijon
# 15                Osasuna
# 16                 Malaga
# 17                 Oviedo
# 18               Mallorca
# 19             Las Palmas
# 21                Granada
# 22         Rayo Vallecano
# 23                  Elche
# 25               Hercules
# 26               Tenerife
# 27                 Murcia
# 28                 Alaves
# 29                Levante
# 30              Salamanca
# 31               Sabadell
# 32                  Cadiz
# 34              Castellon
# 37                Cordoba
# 39             Recreativo
# 40              Burgos CF
# 41             Pontevedra
# 46              Gimnastic
# 49               Alcoyano
# 50                   Jaen
# 52             AD Almeria
# 54                 Lleida
# 57                 Condal
# ...

# %% [markdown]
# # Print the list of teams which came Top 5 in terms of points

# %%
laliga1 = laliga.astype({'Points':'int64','GamesWon':'int64','GoalsAgainst':'int64','GoalsFor':'int64','GamesPlayed':'int64'})

# %%
laliga1.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points            int64
# GamesPlayed       int64
# GamesWon          int64
# GamesDrawn       object
# GamesLost        object
# GoalsFor          int64
# GoalsAgainst      int64
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# dtype: object

# %%
laliga1.nlargest(5,'Points')[['Team','Points']]
# Out:
#               Team  Points
# 0      Real Madrid    4385
# 1        Barcelona    4262
# 2  Atletico Madrid    3442
# 3         Valencia    3386
# 4  Athletic Bilbao    3368

# %% [markdown]
# # Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference.

# %% [markdown]
# Function for finding the Goal Difference

# %%
def Goal_diff_count(x,y):
    a=x-y
    return a

# %%
laliga1['GoalDiff'] = Goal_diff_count(laliga1['GoalsFor'] ,laliga1['GoalsAgainst'] )

# %% [markdown]
# Team with Minimum Goal Difference

# %%
laliga1.nsmallest(1,'GoalDiff')[['Team','GoalDiff']]
# Out:
#                 Team  GoalDiff
# 13  Racing Santander      -525

# %% [markdown]
# Team with Minimum Goal Difference

# %%
laliga1.nlargest(1,'GoalDiff')[['Team','GoalDiff']]
# Out:
#           Team  GoalDiff
# 0  Real Madrid      2807

# %% [markdown]
# # Create a new column with the name “Winning Percent” and append it to the data set

# %% [markdown]
# Function for finding the winning percent

# %%
def winning_perc(x):
    GamesWon ,GamesPlayed = x
    if (GamesPlayed == 0):
        Winning_Percent = 0
    else:
        Winning_Percent  = (GamesWon/GamesPlayed) *100 
    return Winning_Percent

# %% [markdown]
# Appending Winning Percent Column to the dataset

# %%
laliga1['Winning Percent'] = laliga1[['GamesWon','GamesPlayed']].apply(winning_perc, axis = 1)

# %%
laliga1
# Out:
#     Pos              Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0     1       Real Madrid       86    4385         2762      1647        552
# 1     2         Barcelona       86    4262         2762      1581        573
# 2     3   Atletico Madrid       80    3442         2614      1241        598
# 3     4          Valencia       82    3386         2664      1187        616
# 4     5   Athletic Bilbao       86    3368         2762      1209        633
# ..  ...               ...      ...     ...          ...       ...        ...
# 56   57             Xerez        1      34           38         8         10
# 57   58            Condal        1      22           30         7          8
# 58   59   Atletico Tetuan        1      19           30         7          5
# 59   60  Cultural Leonesa        1      14           30         5          4
# 60   61            Girona        1       0            0         0          0
#
# ...

# %% [markdown]
# Top 5 teams which have the highest Winning percentage

# %%
laliga1.nlargest(5,'Winning Percent')[['Team','Winning Percent']]
# Out:
#               Team  Winning Percent
# 0      Real Madrid        59.630702
# 1        Barcelona        57.241130
# 2  Atletico Madrid        47.475134
# 3         Valencia        44.557057
# 4  Athletic Bilbao        43.772629

# %% [markdown]
# # Group teams based on their “Best position” and print the sum of their points for all positions

# %%
laliga1.groupby(["Team","BestPosition"])["Points"].agg(["sum"]).sort_values('sum', ascending=False)
# Out:
#                                 sum
# Team             BestPosition
# Real Madrid      1             4385
# Barcelona        1             4262
# Atletico Madrid  1             3442
# Valencia         1             3386
# Athletic Bilbao  1             3368
# ...                             ...
# Xerez            20              34
# Condal           16              22
# Atletico Tetuan  16              19
# Cultural Leonesa 15              14
# Girona           9                0
#
# [61 rows x 1 columns]
